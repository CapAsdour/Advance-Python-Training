# %%
import pandas as pd
# %matplotlib inline
# or  import matplotlib.pyplot
dfs=pd.read_excel("SampleData.xlsx")
dfs
# Out:
#     Unnamed: 0                                            Address  \
# 0            1  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 1            2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2            3                                               R380
# 3            4                           Holmes HEPA Air Purifier
# 4            5  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 5            6  Angle-D Binders with Locking Rings, Label Holders
# 6            7            SAFCO Mobile Desk Side File, Wire Frame
# 7            8              SAFCO Commercial Wire Shelving, Black
# 8            9                                          Xerox 198
# 9           10                                         Xerox 1980
# 10          11    Advantus Map Pennant Flags and Round Head Tacks
# 11          12                           Holmes HEPA Air Purifier
# 12          13  DS/HD IBM Formatted Diskettes, 200/Pack - Staples
# ...

# %%
pd.read_csv('gapminder.tsv',sep='\t')

# %%
df=pd.read_csv('gapminder.tsv',sep='\t')
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
# 5       Afghanistan
# 6       Afghanistan
# 7       Afghanistan
# 8       Afghanistan
# 9       Afghanistan
# 10      Afghanistan
# 11      Afghanistan
# 12          Albania
# 13          Albania
# 14          Albania
# 15          Albania
# 16          Albania
# 17          Albania
# 18          Albania
# 19          Albania
# 20          Albania
# 21          Albania
# 22          Albania
# 23          Albania
# 24          Algeria
# 25          Algeria
# 26          Algeria
# 27          Algeria
# 28          Algeria
# 29          Algeria
#            ...
# 1674    Yemen, Rep.
# 1675    Yemen, Rep.
# 1676    Yemen, Rep.
# 1677    Yemen, Rep.
# 1678    Yemen, Rep.
# 1679    Yemen, Rep.
# 1680         Zambia
# 1681         Zambia
# 1682         Zambia
# 1683         Zambia
# 1684         Zambia
# 1685         Zambia
# 1686         Zambia
# 1687         Zambia
# ...

# %%
#we can save the sliced data 
country_df=df['country']
country_df.head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
#Extracting multiple columns
subset=df[['country','continent','year']]
subset.head()
# Out:
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972

# %%
#Extracting columns without using column-name

# %%
sub=df.iloc[:,range(1,4)]
sub.head()
# Out:
#   continent  year  lifeExp
# 0      Asia  1952   28.801
# 1      Asia  1957   30.332
# 2      Asia  1962   31.997
# 3      Asia  1967   34.020
# 4      Asia  1972   36.088

# %%
sub=df.iloc[:,range(1,5,2)]
sub.head()
# Out:
#   continent  lifeExp
# 0      Asia   28.801
# 1      Asia   30.332
# 2      Asia   31.997
# 3      Asia   34.020
# 4      Asia   36.088

# %%
df_firstrow=df.loc[0]
df_firstrow
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
df_row100=df.loc[99]
df_row100
# Out:
# country      Bangladesh
# continent          Asia
# year               1967
# lifeExp          43.453
# pop            62821884
# gdpPercap       721.186
# Name: 99, dtype: object

# %%
df_rowx=df.loc[[0,99,999],['country','continent','year']]
df_rowx
# Out:
#          country continent  year
# 0    Afghanistan      Asia  1952
# 99    Bangladesh      Asia  1967
# 999     Mongolia      Asia  1967

# %%
df.loc[df.shape[0]-1]
# Out:
# country      Zimbabwe
# continent      Africa
# year             2007
# lifeExp        43.487
# pop          12311143
# gdpPercap     469.709
# Name: 1703, dtype: object

# %%
df.ix[0,'continent']
# Out:
# C:\Users\asitk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 'Asia'

# %%
df.ix[0]
# Out:
# C:\Users\asitk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
df.ix[[0,99,999],['country','continent','year']]
# Out:
# C:\Users\asitk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#          country continent  year
# 0    Afghanistan      Asia  1952
# 99    Bangladesh      Asia  1967
# 999     Mongolia      Asia  1967

# %%
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df.groupby('year')['lifeExp'].mean().plot()

# %%
#write a program to import excel data in pandas and insert a column in the sixth position in excel sheet and fill it with NaN

# %%
import pandas
import numpy as np
df=pandas.read_excel('SampleData.xlsx')
df.insert(6,"column1",np.nan)
print(df.head)
# Out:
# <bound method NDFrame.head of     Unnamed: 0                                            Address  \
# 0            1  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 1            2   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2            3                                               R380
# 3            4                           Holmes HEPA Air Purifier
# 4            5  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 5            6  Angle-D Binders with Locking Rings, Label Holders
# 6            7            SAFCO Mobile Desk Side File, Wire Frame
# 7            8              SAFCO Commercial Wire Shelving, Black
# 8            9                                          Xerox 198
# 9           10                                         Xerox 1980
# 10          11    Advantus Map Pennant Flags and Round Head Tacks
# 11          12                           Holmes HEPA Air Purifier
# 12          13  DS/HD IBM Formatted Diskettes, 200/Pack - Staples
# ...

# %%
data={'first_name':['Meena','Sudhir','Kumar'],'age':[23,48,16],'city':['Mumbai','Boston','Sydney']}
df_x=pandas.DataFrame(data,columns=['first_name','age','city'])
df_x
# Out:
#   first_name  age    city
# 0      Meena   23  Mumbai
# 1     Sudhir   48  Boston
# 2      Kumar   16  Sydney

# %%
city_of_country={'Mumbai':'India','sydney':'Australia'}
city_of_country
# Out:
# {'Mumbai': 'India', 'sydney': 'Australia'}

# %%
df_x['country']=df_x['city'].map(city_of_country)
df_x
# Out:
#   first_name  age    city country
# 0      Meena   23  Mumbai   India
# 1     Sudhir   48  Boston     NaN
# 2      Kumar   16  Sydney     NaN

# %%
capitalizer=lambda x:x.upper()
df_x['FN']=df_x['first_name'].apply(capitalizer)
df_x
# Out:
#   first_name  age    city country      FN
# 0      Meena   23  Mumbai   India   MEENA
# 1     Sudhir   48  Boston     NaN  SUDHIR
# 2      Kumar   16  Sydney     NaN   KUMAR

# %%
data_y={'height':[74,52,5,27],'age':[81,64,4,25]}
df_y=pandas.DataFrame(data,columns=['height','age'])
df_y
# Out:
#    height  age
# 0      74   81
# 1      52   64
# 2       5    4
# 3      27   25

# %%
df_y.applymap(np.sqrt)
# Out:
#      height  age
# 0  8.602325  9.0
# 1  7.211103  8.0
# 2  2.236068  2.0
# 3  5.196152  5.0

# %%
#plot a map on the tsv file taking any two columns

# %%
import pandas as pd
# %matplotlib inline
df=pd.read_csv('gapminder.tsv',sep='\t')
y=df.groupby('country')['lifespan'].mean().plot()
print(y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-4533d49c6afb> in <module>
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3 df=pd.read_csv('gapminder.tsv',sep='\t')
# ----> 4 y=df.groupby('country')['lifespan'].mean().plot()
#       5 print(y)
#
# ~\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     273         else:
#     274             if key not in self.obj:
# --> 275                 raise KeyError("Column not found: {key}".format(key=key))
#     276             return self._gotitem(key, ndim=1)
#     277
#
# KeyError: 'Column not found: lifespan'
